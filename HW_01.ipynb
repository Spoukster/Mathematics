# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
k1 = 1
k2 = 2.5
plt.plot(x, np.cos(k1 * x), label='k = 1')
plt.plot(x, np.cos(k2 * x), label='k = 2.5')
plt.ylim(-1.5, 2)
plt.legend(loc='upper right')
